# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
#
# ## <font color='blue'>Fundamentos de Linguagem Python Para Análise de Dados e Data Science</font>
#
# ## <font color='blue'>Projeto 2</font>
#
# ## <font color='blue'>Análise Exploratória de Dados em Linguagem Python Para a Área de Varejo</font>

# %% [markdown]
# ![DSA](imagens/projeto2.png)

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.19

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# ## Carregando os Dados

# %%
# Carrega o dataset
df_dsa = pd.read_csv('dados/dataset.csv')

# %%
# Shape
df_dsa.shape
# Out:
# (9700, 11)

# %%
# Amostra dos dados
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %%
# Amostra dos dados
df_dsa.tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 9695  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9696  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9697  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9698  CA-2017-105291  30/10/2017   SP-20920     Consumer  United States
# 9699  CA-2018-147032  31/07/2018   LB-16795  Home Office  United States
#
#                Cidade      Estado       ID_Produto        Categoria  \
# 9695        Inglewood  California  OFF-PA-10004569  Office Supplies
# 9696        Inglewood  California  OFF-AP-10000027  Office Supplies
# 9697        Inglewood  California  TEC-PH-10000675       Technology
# 9698  San Luis Obispo  California  OFF-FA-10003059  Office Supplies
# 9699       Wilmington    Delaware  OFF-PA-10003256  Office Supplies
#
#      SubCategoria  Valor_Venda
# 9695        Paper       22.830
# 9696   Appliances       54.320
# ...

# %% [markdown]
# ## Análise Exploratória

# %%
# Colunas do conjunto de dados
df_dsa.columns
# Out:
# Index(['ID_Pedido', 'Data_Pedido', 'ID_Cliente', 'Segmento', 'Pais', 'Cidade',
#        'Estado', 'ID_Produto', 'Categoria', 'SubCategoria', 'Valor_Venda'],
#       dtype='object')

# %%
# Verificando o tipo de dado de cada coluna
df_dsa.dtypes
# Out:
# ID_Pedido        object
# Data_Pedido      object
# ID_Cliente       object
# Segmento         object
# Pais             object
# Cidade           object
# Estado           object
# ID_Produto       object
# Categoria        object
# SubCategoria     object
# Valor_Venda     float64
# dtype: object

# %%
# Resumo estatístico da coluna com o valor de venda
df_dsa['Valor_Venda'].describe()
# Out:
# count     9700.000000
# mean       230.469892
# std        627.504252
# min          0.444000
# 25%         17.248000
# 50%         54.272000
# 75%        209.932500
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
# Verificando se há registros duplicados
df_dsa[df_dsa.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID_Pedido, Data_Pedido, ID_Cliente, Segmento, Pais, Cidade, Estado, ID_Produto, Categoria, SubCategoria, Valor_Venda]
# Index: []

# %%
# Verificando de há valores ausentes
df_dsa.isnull().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Cidade          0
# Estado          0
# ID_Produto      0
# Categoria       0
# SubCategoria    0
# Valor_Venda     0
# dtype: int64

# %%
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %%
df_dsa['Data_Pedido'].value_counts()
# Out:
# Data_Pedido
# 05/09/2017    38
# 10/11/2017    35
# 01/12/2018    34
# 02/09/2018    33
# 09/12/2018    32
#               ..
# 16/08/2015     1
# 27/03/2016     1
# 05/01/2015     1
# 11/02/2017     1
# 10/06/2015     1
# Name: count, Length: 1226, dtype: int64

# %% [markdown]
# ## Pergunta de Negócio 1:
#
# ### Qual Cidade com Maior Valor de Venda de Produtos da Categoria 'Office Supplies'?

# %%
#Filtrando para os ocorrencias de Office Supplies em Categoria
df1 = df_dsa[df_dsa['Categoria'] == 'Office Supplies']

#Agrupando e ordenando (crescente) pelas cidades com o valor_venda
df1 = df1.groupby('Cidade')['Valor_Venda'].sum().sort_values()

#retornando o ultimo indice da ordenacao
df1.idxmax()
# Out:
# 'New York City'

# %% [markdown]
# ### R - A cidade que obteve maior valor de vendas da categoria Office Supplies foi 'New York City'

# %% [markdown]
# ## Pergunta de Negócio 2:
#
# ### Qual o Total de Vendas Por Data do Pedido?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
#agrupando por data e somando os valores de venda
df2 = df_dsa.groupby('Data_Pedido')['Valor_Venda'].sum()

#alterando o tamanho do grafico
plt.figure(figsize = (20,6))
#configurando titulo e eixos do grafico
df2.plot(x = 'Data_Pedido', y = 'Valor_Venda')
plt.title('Total de vendas por data do pedido')
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 3:
#
# ### Qual o Total de Vendas por Estado?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
#Agrupando por estado e somando os valores de venda
#reset_index usado para reorganizar os indices
df3 = df_dsa.groupby('Estado')['Valor_Venda'].sum().reset_index()

plt.figure(figsize = (20,6))
df3.plot.bar(x = 'Estado', y = 'Valor_Venda', width=0.6, color='red')
plt.title('Total de vendas por estado')
#rotaciona os nomes no eixo x
plt.xticks(rotation=80)

#tight_layout ajusta automaticamente para evitar sobreposicao
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 4:
#
# ### Quais São as 10 Cidades com Maior Total de Vendas?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
df4 = df_dsa.groupby('Cidade')['Valor_Venda'].sum().sort_values(ascending=False).head(10).plot.bar(x = 'Cidade', y =  'Valor_Venda', color='green')
plt.title('Top 10 cidades com maior total de vendas')
# Out:
# Text(0.5, 1.0, 'Top 10 cidades com maior total de vendas')

# %% [markdown]
# ## Pergunta de Negócio 5:
#
# ### Qual Segmento Teve o Maior Total de Vendas?
#
# Demonstre o resultado através de um gráfico de pizza.

# %%
df5 = df_dsa.groupby('Segmento')['Valor_Venda'].sum().reset_index().sort_values(by = 'Valor_Venda', ascending=False)

# %%
def valor_total(values):
    def my_format(pct):
        total = sum(values)
        val = int(round(pct * total / 100.0))
        return f'$ {val}'
    return my_format

# %%
plt.figure(figsize=(16,6))

plt.pie(df5['Valor_Venda'], labels = df5['Segmento'], autopct= valor_total(df5['Valor_Venda']), startangle= 90)

plt.title('Total de vendas por segmento')
# Out:
# Text(0.5, 1.0, 'Total de vendas por segmento')

# %% [markdown]
# ## Pergunta de Negócio 6 (Desafio Nível Baby):
#
# ### Qual o Total de Vendas Por Segmento e Por Ano?

# %%
df6 = df_dsa.copy()
#convertendo a data para um tipo adequado
df6['Data_Pedido'] = pd.to_datetime(df6['Data_Pedido'], dayfirst= True)
#criando a coluna ano e colocando o ano correspondente
df6['Ano'] = df6['Data_Pedido'].dt.year

df6_grouped = df6.groupby(['Segmento', 'Ano'])['Valor_Venda'].sum()
df6_grouped
# Out:
# Segmento     Ano
# Consumer     2015    256719.9166
#              2016    265295.2593
#              2017    288459.5572
#              2018    323359.6019
# Corporate    2015    125819.5957
#              2016    114643.1229
#              2017    203266.7398
#              2018    235502.7284
# Home Office  2015     88229.0878
#              2016     74134.1332
#              2017    103639.6270
#              2018    156488.5849
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# ## Pergunta de Negócio 7 (Desafio Nível Júnior):
#
# Os gestores da empresa estão considerando conceder diferentes faixas de descontos e gostariam de fazer uma simulação com base na regra abaixo:
#
# - Se o Valor_Venda for maior que 1000 recebe 15% de desconto.
# - Se o Valor_Venda for menor que 1000 recebe 10% de desconto.
#
# ### Quantas Vendas Receberiam 15% de Desconto?

# %%
#cria uma copia do df original
df7 = df_dsa.copy()

#cria a coluna desconto e aplica o valor seguindo a regra proposta
df7['Desconto'] = np.where(df7['Valor_Venda'] > 1000, 0.15, 0.10)
df7.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda  Desconto
# 0     261.9600       0.1
# 1     731.9400       0.1
# ...

# %%
#mostrando quantas vendas recebem cada desconto
df7['Desconto'].value_counts()
# Out:
# Desconto
# 0.10    9243
# 0.15     457
# Name: count, dtype: int64

# %% [markdown]
# ### R - O numero de vendas com 15% de desconto é 457

# %% [markdown]
# ## Pergunta de Negócio 8 (Desafio Nível Master):
#
# ### Considere Que a Empresa Decida Conceder o Desconto de 15% do Item Anterior. Qual Seria a Média do Valor de Venda Antes e Depois do Desconto?

# %%
#criando copia do df original
df8 = df7.copy()

#criando coluna do valor da venda com desconto aplicado
df8['Valor_Venda_com_Desconto'] = df8['Valor_Venda'] - (df8['Valor_Venda'] * df8['Desconto']) 
df8.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda  Desconto  Valor_Venda_com_Desconto
# ...

# %%
#Filtrando o df para obter apenas as vendas que tiveram 14% de desconto
df8_com_desconto15 = df8.query('Desconto == 0.15')
df8_com_desconto15
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 10    CA-2015-115812  09/06/2015   BH-11710     Consumer  United States
# 24    CA-2016-106320  25/09/2016   EB-13870     Consumer  United States
# 27    US-2016-150630  17/09/2016   TB-21520     Consumer  United States
# 35    CA-2017-117590  08/12/2017   GH-14485    Corporate  United States
# 54    CA-2017-105816  11/12/2017   JM-15265    Corporate  United States
# ...              ...         ...        ...          ...            ...
# 9632  CA-2015-151330  14/10/2015   TC-21295     Consumer  United States
# 9636  CA-2016-116638  28/01/2016   JH-15985     Consumer  United States
# 9646  CA-2017-107104  26/11/2017   MS-17365     Consumer  United States
# 9657  CA-2017-160717  06/06/2017   ME-17320  Home Office  United States
# 9670  CA-2017-114867  23/12/2017   FM-14290  Home Office  United States
#
#              Cidade          Estado       ID_Produto   Categoria SubCategoria  \
# ...

# %%
df8_com_desconto15[['Valor_Venda', 'Valor_Venda_com_Desconto']].mean()
# Out:
# Valor_Venda                 2116.807815
# Valor_Venda_com_Desconto    1799.286643
# dtype: float64

# %% [markdown]
# ## Pergunta de Negócio 9 (Desafio Nível Master Ninja):
#
# ### Qual o Média de Vendas Por Segmento, Por Ano e Por Mês?
#
# Demonstre o resultado através de gráfico de linha.

# %%
#criando uma copia do df6 (pois ele ja a data tratada)
df9 = df6.copy()

#adicionando a coluna mes
df9['Mes'] = df9['Data_Pedido'].dt.month
df9.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Mes
# 0     261.9600  2017   11
# 1     731.9400  2017   11
# ...

# %%
df9_grouped = df9.groupby(['Ano', 'Mes', 'Segmento'])['Valor_Venda'].agg([np.sum, np.mean, np.median])
df9_grouped
# Out:
# /tmp/ipykernel_9052/4036751408.py:1: FutureWarning: The provided callable <function sum at 0x7f925454cf70> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df9_grouped = df9.groupby(['Ano', 'Mes', 'Segmento'])['Valor_Venda'].agg([np.sum, np.mean, np.median])
# /tmp/ipykernel_9052/4036751408.py:1: FutureWarning: The provided callable <function mean at 0x7f9254550ee0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df9_grouped = df9.groupby(['Ano', 'Mes', 'Segmento'])['Valor_Venda'].agg([np.sum, np.mean, np.median])
# ...

# %% [markdown]
# ## Pergunta de Negócio 10 (Desafio Nível Master Ninja das Galáxias):
#
# ### Qual o Total de Vendas Por Categoria e SubCategoria, Considerando Somente as Top 12 SubCategorias?
#
# Demonstre tudo através de um único gráfico.

# %%
df10_dsa_p10 = df_dsa.copy()

# %%
# Agrupamos por categoria e subcategoria e calculamos a soma somente para variáveus numéricas
df_dsa_p10 = df_dsa.groupby(['Categoria',
                             'SubCategoria']).sum(numeric_only = True).sort_values('Valor_Venda',
                                                                                   ascending = False).head(12)

# %%
# Convertemos a coluna Valor_Venda em número inteiro e classificamos por categoria
df_dsa_p10 = df_dsa_p10[['Valor_Venda']].astype(int).sort_values(by = 'Categoria').reset_index()

# %%
# Dataframe com categorias e subcategorias
df_dsa_p10
# Out:
#           Categoria SubCategoria  Valor_Venda
# 0         Furniture       Chairs       317919
# 1         Furniture       Tables       202083
# 2         Furniture    Bookcases       108045
# 3         Furniture  Furnishings        88862
# 4   Office Supplies      Storage       216188
# 5   Office Supplies      Binders       194723
# 6   Office Supplies   Appliances       104061
# 7   Office Supplies        Paper        76312
# 8        Technology       Phones       325271
# 9        Technology     Machines       189238
# 10       Technology  Accessories       162791
# 11       Technology      Copiers       146248

# %%
# Criamos outro dataframe somente com os totais por categoria
df_dsa_p10_cat = df_dsa_p10.groupby('Categoria').sum(numeric_only = True).reset_index()

# %%
# Dataframe com categorias 
df_dsa_p10_cat
# Out:
#          Categoria  Valor_Venda
# 0        Furniture       716909
# 1  Office Supplies       591284
# 2       Technology       823548

# %%
# Listas de cores para categorias
cores_categorias = ['#5d00de',
                    '#0ee84f',
                    '#e80e27']

# %%
# Listas de cores para subcategorias
cores_subcategorias = ['#aa8cd4',
                       '#aa8cd5',
                       '#aa8cd6',
                       '#aa8cd7',
                       '#26c957',
                       '#26c958',
                       '#26c959',
                       '#26c960',
                       '#e65e65',
                       '#e65e66',
                       '#e65e67',
                       '#e65e68']

# %%
# Função para converter os dados em valor absoluto
def autopct_format(values): 
    def my_format(pct): 
        total = sum(values) 
        val = int(round(pct * total / 100.0))
        return ' $ {v:d}'.format(v = val)
    return my_format

# %%
# Plot

# Tamanho da figura
fig, ax = plt.subplots(figsize = (18,12))

# Gráfico das categorias
p1 = ax.pie(df_dsa_p10_cat['Valor_Venda'], 
            radius = 1,
            labels = df_dsa_p10_cat['Categoria'],
            wedgeprops = dict(edgecolor = 'white'),
            colors = cores_categorias)

# Gráfico das subcategorias
p2 = ax.pie(df_dsa_p10['Valor_Venda'],
            radius = 0.9,
            labels = df_dsa_p10['SubCategoria'],
            autopct = autopct_format(df_dsa_p10['Valor_Venda']),
            colors = cores_subcategorias, 
            labeldistance = 0.7,
            wedgeprops = dict(edgecolor = 'white'), 
            pctdistance = 0.53,
            rotatelabels = True)

# Limpa o centro do círculo
centre_circle = plt.Circle((0, 0), 0.6, fc = 'white')

# Labels e anotações
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.annotate(text = 'Total de Vendas: ' + '$ ' + str(int(sum(df_dsa_p10['Valor_Venda']))), xy = (-0.2, 0))
plt.title('Total de Vendas Por Categoria e Top 12 SubCategorias')
plt.show()

# %% [markdown]
# # Fim
